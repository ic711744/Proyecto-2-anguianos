# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Precipitaciones promedio medido mensualmente en Jalisco en el transcurso del 2019

# %%
archivo="precipitaciones_jal.csv"
tabla=pd.read_csv(file_name, index_col=0)
tabla
# Out:
#             Precipitación (mm)
# Meses
# Enero                      8.4
# Febrero                    1.1
# Marzo                      0.1
# Abril                      0.1
# Mayo                       6.0
# Junio                     96.3
# Julio                    217.7
# Agosto                   171.7
# Septiembre               239.8
# Octubre                  128.6
# Noviembre                 50.5
# Diciembre                  6.1

# %% [markdown]
# ## A continuación un gráfico de los mm de agua en el transcurso de los meses

# %%
tabla.plot(figsize=(20,10),legend=True);

# %% [markdown]
# ## Sacamos promedio y desviación de acuerdo a los datos brindados

# %%
A= tabla.iloc[:,0].mean()
B = tabla.iloc[:,0].std()
A,B
# Out:
# (77.2, 91.13777781718483)

# %%
def Slluvias(A,B,nd,ns,dia):
    fechas = pd.date_range(start = dia,periods=nd)
    rs = B*np.random.randn(nd,ns)+A
    return pd.DataFrame(index=fechas, data=rs)

# %% [markdown]
# ## Se busca construir una calle y se necesita diseñar para el mes más critico en este caso septiembre para evitar inundaciones por lo que se hacen 50 simulaciones de ese mes para el 2020.

# %%
Simulacion = Slluvias(A,B,30,50,"2020-09-01")
Simulacion
# Out:
#                     0           1           2           3           4   \
# 2020-09-01 -118.749580  -17.010567   44.133973   28.434922  228.056786
# 2020-09-02   58.100241   65.263740  151.554898  141.850430   -8.481338
# 2020-09-03  138.075090   43.882380   65.953145  183.023399   32.083609
# 2020-09-04  151.548062   41.346179  191.605951   46.120835   72.210938
# 2020-09-05  118.265042    9.367202  106.372612  152.054682  -29.512507
# 2020-09-06  209.033641   88.847154 -107.146740  123.960327  231.087027
# 2020-09-07   38.290097   99.672255  112.253600   32.284463  153.758276
# 2020-09-08  -34.816886   64.389024  304.783518  239.057949  -16.342290
# 2020-09-09   -7.037810   24.038538  109.256154   66.824439  160.190330
# 2020-09-10    9.041689  -58.644852   46.834931  269.675588   99.811766
# 2020-09-11   34.458692  -42.311765    2.809419  -13.579280   70.114070
# 2020-09-12 -143.775812  112.194646    4.277197  136.854141   52.866961
# ...

# %% [markdown]
# ## Grafica de la simulacion de precipitaciones en mm en el mes de septiembre del 2020

# %%
Simulacion.plot(figsize=(25,18),legend=True);

# %% [markdown]
# ## Con esta simulación podemos buscar el factor más critico y diseñar nuestro tramo a construir para ese tipo de mm y poder evitar inundaciones.
